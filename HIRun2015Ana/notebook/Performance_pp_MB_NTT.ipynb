# %% [markdown]
# # Performance plots for pp_MB_NTT in pT and $\eta$.
#
# - pp
# - MinBias Sample
# - Non-Track-Trigger cuts

# %%
from IPython.display import Image
pathname = "../files/"

efficiencyName = "AbsoluteEfficiency_pp_MB_NTT_20160119.png"
fakeName = "FakeRate_pp_MB_NTT_20160119.png"
SecondaryName = "SecondaryReconstruction_pp_MB_NTT_20160119.png"
MultipleName = "MultipleReconstruction_pp_MB_NTT_20160119.png"

Image(filename = pathname + efficiencyName)

# %%
Image(filename = pathname + fakeName)

# %%
Image(filename = pathname + SecondaryName)

# %%
Image(filename = pathname + MultipleName)
